# %%
import pandas as pd

# %%
v_info = pd.read_pickle("../data/NEWS/KBS/KBS_130905_220831.pkl")

# %%
v_info
# Out:
#             video_id                  time                channel_id  \
# 0        08AuIfhmyDU  2013-09-05T01:55:10Z  UCcQTRi69dsVYHN3exePtZ1A
# 1        08AuIfhmyDU  2013-09-05T01:55:10Z  UCcQTRi69dsVYHN3exePtZ1A
# 2        08AuIfhmyDU  2013-09-05T01:55:10Z  UCcQTRi69dsVYHN3exePtZ1A
# 3        08AuIfhmyDU  2013-09-05T01:55:10Z  UCcQTRi69dsVYHN3exePtZ1A
# 4        08AuIfhmyDU  2013-09-05T01:55:10Z  UCcQTRi69dsVYHN3exePtZ1A
# ...              ...                   ...                       ...
# 1926400  lle0fonUM7k  2022-08-31T00:28:30Z  UCcQTRi69dsVYHN3exePtZ1A
# 1926401  lle0fonUM7k  2022-08-31T00:28:30Z  UCcQTRi69dsVYHN3exePtZ1A
# 1926402  lle0fonUM7k  2022-08-31T00:28:30Z  UCcQTRi69dsVYHN3exePtZ1A
# 1926403  lle0fonUM7k  2022-08-31T00:28:30Z  UCcQTRi69dsVYHN3exePtZ1A
# 1926404  AQCCHATcCwI  2022-08-31T12:40:22Z  UCcQTRi69dsVYHN3exePtZ1A
#
#                                                video_title  \
# 0                                      키 크는 수술...'6cm'의 함정
# ...

# %%
v_info[['video_id', 'video_title']].drop_duplicates()
# Out:
#             video_id                                        video_title
# 0        08AuIfhmyDU                                키 크는 수술...'6cm'의 함정
# 142      TM6CGWa4KBI                                         "전세 있습니까?"
# 144      8DVsWQChY0Y                                [57회]] 여자의 고민 '갱년기'
# 148      ygvHWqa4GbU                             [알약튼튼] 건강한 골반을 위한 스트레칭
# 149      p6JYdl72tYY                          [56회] '굿닥터'가 말하는 소아외과의 진실
# ...              ...                                                ...
# 1925388  YjhkSYUQC6c  [풀영상] 코로나19 통합뉴스룸 : 신규 확진 103,961명…위중증 569명 - ...
# 1925618  lle0fonUM7k  제11호 태풍 ‘힌남노’ 제주 영향 촉각…‘가을 태풍’ 주의 / KBS  2022....
# 1925636  q1hJqFMl1SM                 론스타 분쟁 한국정부 패소…“2억 1,650만 달러 배상하라”
# 1925661  lDxV3WvPBXE  [31일 0시 기준] 신규 확진 10만 3,961명…위중증 569명·사망 75명 /...
# 1925728  Vm2WPiKsIw0   입국 전 코로나19 검사 폐지·개량 백신 4분기 도입 / KBS  2022.08.31.
#
# [43528 rows x 2 columns]

# %%
v_info[['video_id', 'video_title']].drop_duplicates().to_csv("../data/KBS_1309_2208_title.csv")
